# %%
import heartpy as hp
import numpy as np
import matplotlib.pyplot as plt

# %%
file = 'ppg_stress.csv'

# %%
# load the PPG signal (fs = 400Hz)
data = hp.get_data(file)
time = data[1:][:, 0]
fs = 1/time[0]
ppg = data[1:][:, 1]

# and visualise
plt.figure(figsize=(20,10))
plt.plot(ppg)
plt.show()

# %%
# zoom in
plt.figure(figsize=(20,10))
plt.plot(ppg[10500:12000])
plt.show()

# %%
# scale  (optional; might affect performance)
scaled = hp.scale_data(ppg, lower=0, upper=1)
plt.figure(figsize=(20,10))
plt.plot(scaled)
plt.show()

# %%
# enhance peaks
enhanced = hp.enhance_peaks(ppg, iterations=1)
plt.figure(figsize=(20,10))
plt.plot(enhanced)
plt.show()

# %%
# filter
filtered = hp.filter_signal(scaled, cutoff=[0.75, 3], sample_rate=fs, order=1, filtertype='bandpass')
plt.figure(figsize=(20,10))
plt.plot(filtered)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(filtered[10500:12000])
plt.show()

# %%
# compute HRV
wd, m = hp.process(filtered, sample_rate=fs, calc_freq=True, freq_method='fft', high_precision=True, clean_rr=True)

# plot
plt.figure(figsize=(20,3))
hp.plotter(wd, m)

for measure in m.keys():
    print('%s: %f' %(measure, m[measure]))
# Out:
# bpm: 103.616312
# ibi: 579.059406
# sdnn: 40.956919
# sdsd: 38.900578
# rmssd: 38.900578
# pnn20: 0.268657
# pnn50: 0.079602
# hr_mad: 24.500000
# breathingrate: 0.308770
# lf: 189.926992
# hf: 126.541064
# lf/hf: 1.500912

# %%
# sliding window analysis
def window(a, w, o, copy = False):
    sh = (a.size - w + 1, w)
    st = a.strides * 2
    o = int(o * w);
    view = np.lib.stride_tricks.as_strided(a, strides = st, shape = sh)[0::o]
    if copy:
        return view.copy()
    else:
        return view
    
ppgs = window(filtered, int(fs)*30, 0.2) # 30 seconds window

for p in ppgs:
    # compute HRV
    wd, m = hp.process(filtered, sample_rate=fs, calc_freq=True, freq_method='fft', high_precision=True, clean_rr=True)

    # plot
    plt.figure(figsize=(20,10))
    hp.plotter(wd, m)

    for measure in m.keys():
        print('%s: %f' %(measure, m[measure]))
# Out:
# bpm: 103.616312
# ibi: 579.059406
# sdnn: 40.956919
# sdsd: 38.900578
# rmssd: 38.900578
# pnn20: 0.268657
# pnn50: 0.079602
# hr_mad: 24.500000
# breathingrate: 0.308770
# lf: 189.926992
# hf: 126.541064
# lf/hf: 1.500912
# bpm: 103.616312
# ibi: 579.059406
# sdnn: 40.956919
# sdsd: 38.900578
# rmssd: 38.900578
# pnn20: 0.268657
# pnn50: 0.079602
# hr_mad: 24.500000
# breathingrate: 0.308770
# lf: 189.926992
# hf: 126.541064
# lf/hf: 1.500912
# bpm: 103.616312
# ibi: 579.059406
# sdnn: 40.956919
# sdsd: 38.900578
# rmssd: 38.900578
# pnn20: 0.268657
# pnn50: 0.079602
# hr_mad: 24.500000
# breathingrate: 0.308770
# lf: 189.926992
# hf: 126.541064
# lf/hf: 1.500912
# bpm: 103.616312
# ibi: 579.059406
# sdnn: 40.956919
# sdsd: 38.900578
# rmssd: 38.900578
# pnn20: 0.268657
# pnn50: 0.079602
# hr_mad: 24.500000
# breathingrate: 0.308770
# lf: 189.926992
# hf: 126.541064
# lf/hf: 1.500912
# bpm: 103.616312
# ibi: 579.059406
# sdnn: 40.956919
# sdsd: 38.900578
# rmssd: 38.900578
# pnn20: 0.268657
# pnn50: 0.079602
# hr_mad: 24.500000
# breathingrate: 0.308770
# lf: 189.926992
# hf: 126.541064
# lf/hf: 1.500912
# bpm: 103.616312
# ibi: 579.059406
# sdnn: 40.956919
# sdsd: 38.900578
# rmssd: 38.900578
# pnn20: 0.268657
# pnn50: 0.079602
# hr_mad: 24.500000
# breathingrate: 0.308770
# lf: 189.926992
# hf: 126.541064
# lf/hf: 1.500912
# bpm: 103.616312
# ibi: 579.059406
# sdnn: 40.956919
# sdsd: 38.900578
# rmssd: 38.900578
# pnn20: 0.268657
# pnn50: 0.079602
# hr_mad: 24.500000
# breathingrate: 0.308770
# lf: 189.926992
# hf: 126.541064
# lf/hf: 1.500912
# bpm: 103.616312
# ibi: 579.059406
# sdnn: 40.956919
# sdsd: 38.900578
# rmssd: 38.900578
# pnn20: 0.268657
# pnn50: 0.079602
# hr_mad: 24.500000
# breathingrate: 0.308770
# lf: 189.926992
# hf: 126.541064
# lf/hf: 1.500912
# bpm: 103.616312
# ibi: 579.059406
# sdnn: 40.956919
# sdsd: 38.900578
# rmssd: 38.900578
# pnn20: 0.268657
# pnn50: 0.079602
# hr_mad: 24.500000
# breathingrate: 0.308770
# lf: 189.926992
# hf: 126.541064
# lf/hf: 1.500912
# bpm: 103.616312
# ibi: 579.059406
# sdnn: 40.956919
# sdsd: 38.900578
# rmssd: 38.900578
# pnn20: 0.268657
# pnn50: 0.079602
# hr_mad: 24.500000
# breathingrate: 0.308770
# lf: 189.926992
# hf: 126.541064
# lf/hf: 1.500912
# bpm: 103.616312
# ibi: 579.059406
# sdnn: 40.956919
# sdsd: 38.900578
# rmssd: 38.900578
# pnn20: 0.268657
# pnn50: 0.079602
# hr_mad: 24.500000
# breathingrate: 0.308770
# lf: 189.926992
# hf: 126.541064
# lf/hf: 1.500912
# bpm: 103.616312
# ibi: 579.059406
# sdnn: 40.956919
# sdsd: 38.900578
# rmssd: 38.900578
# pnn20: 0.268657
# pnn50: 0.079602
# hr_mad: 24.500000
# breathingrate: 0.308770
# lf: 189.926992
# hf: 126.541064
# lf/hf: 1.500912
# bpm: 103.616312
# ibi: 579.059406
# sdnn: 40.956919
# sdsd: 38.900578
# rmssd: 38.900578
# pnn20: 0.268657
# pnn50: 0.079602
# hr_mad: 24.500000
# breathingrate: 0.308770
# lf: 189.926992
# hf: 126.541064
# lf/hf: 1.500912
# bpm: 103.616312
# ibi: 579.059406
# sdnn: 40.956919
# sdsd: 38.900578
# rmssd: 38.900578
# pnn20: 0.268657
# pnn50: 0.079602
# hr_mad: 24.500000
# breathingrate: 0.308770
# lf: 189.926992
# hf: 126.541064
# lf/hf: 1.500912
# bpm: 103.616312
# ibi: 579.059406
# sdnn: 40.956919
# sdsd: 38.900578
# rmssd: 38.900578
# pnn20: 0.268657
# pnn50: 0.079602
# hr_mad: 24.500000
# breathingrate: 0.308770
# lf: 189.926992
# hf: 126.541064
# lf/hf: 1.500912
# bpm: 103.616312
# ibi: 579.059406
# sdnn: 40.956919
# sdsd: 38.900578
# rmssd: 38.900578
# pnn20: 0.268657
# pnn50: 0.079602
# hr_mad: 24.500000
# breathingrate: 0.308770
# lf: 189.926992
# hf: 126.541064
# lf/hf: 1.500912
# bpm: 103.616312
# ibi: 579.059406
# sdnn: 40.956919
# sdsd: 38.900578
# rmssd: 38.900578
# pnn20: 0.268657
# pnn50: 0.079602
# hr_mad: 24.500000
# breathingrate: 0.308770
# lf: 189.926992
# hf: 126.541064
# lf/hf: 1.500912
